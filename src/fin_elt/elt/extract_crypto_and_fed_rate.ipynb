# %%
import requests
from secrets_config import api_key
import pandas as pd

# %%
# Variables: Note: these are case-sensitive
symbol = 'BTC'
# could also do: symbol = 'ETH'
market = 'USD'

# %%
def extract_crypto_rates(
    symbol:str,
    market:str,
    api_key:str
)->pd.DataFrame:
    base_url = f'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_DAILY&symbol={symbol}&market={market}&apikey={api_key}'
    r = requests.get(base_url)
    response_data = r.json()
    df = pd.DataFrame(response_data['Time Series (Digital Currency Daily)']).transpose().reset_index()
    df = df.rename(columns={ df.columns[0]: "Date" })
    df['Symbol'] = f'{symbol}'
    df['Market'] = f'{market}'
    return df

# %%
extract_crypto_rates(symbol=symbol, market=market, api_key=api_key)
# Out:
#            Date  1a. open (USD)  1b. open (USD)  2a. high (USD)  \
# 0    2022-09-28  19078.10000000  19078.10000000  19238.28000000
# 1    2022-09-27  19226.68000000  19226.68000000  20385.86000000
# 2    2022-09-26  18809.13000000  18809.13000000  19318.96000000
# 3    2022-09-25  18921.99000000  18921.99000000  19180.21000000
# 4    2022-09-24  19288.57000000  19288.57000000  19316.14000000
# ..          ...             ...             ...             ...
# 995  2020-01-07   7758.90000000   7758.90000000   8207.68000000
# 996  2020-01-06   7357.64000000   7357.64000000   7795.34000000
# 997  2020-01-05   7354.19000000   7354.19000000   7495.00000000
# 998  2020-01-04   7345.00000000   7345.00000000   7404.00000000
# 999  2020-01-03   6965.49000000   6965.49000000   7405.00000000
#
#      2b. high (USD)   3a. low (USD)   3b. low (USD) 4a. close (USD)  \
# 0    19238.28000000  19070.22000000  19070.22000000  19121.36000000
# ...

# %%
def extract_fed_funds_rate(
    api_key:str
)->pd.DataFrame:
    base_url = f'https://www.alphavantage.co/query?function=FEDERAL_FUNDS_RATE&interval=daily&apikey={api_key}' 
    r = requests.get(base_url)
    response_data = r.json()
    df = pd.DataFrame(response_data['data'])
    df = df.rename(columns={ df.columns[0]: "Date" })
    df['Symbol'] = f'{symbol}'
    df['Market'] = f'{market}'
    return df

# %%
extract_fed_funds_rate(api_key=api_key)
# Out:
#              Date  value Symbol Market
# 0      2022-09-27   3.08    BTC    USD
# 1      2022-09-26   3.08    BTC    USD
# 2      2022-09-25   3.08    BTC    USD
# 3      2022-09-24   3.08    BTC    USD
# 4      2022-09-23   3.08    BTC    USD
# ...           ...    ...    ...    ...
# 24921  1954-07-05   0.88    BTC    USD
# 24922  1954-07-04  1.250    BTC    USD
# 24923  1954-07-03  1.250    BTC    USD
# 24924  1954-07-02  1.250    BTC    USD
# 24925  1954-07-01   1.13    BTC    USD
#
# [24926 rows x 4 columns]

# %%
# https://www.reddit.com/r/explainlikeimfive/comments/5ii9vk/eli5_what_is_the_federal_funds_rate_and_why_does/
url = f'https://www.alphavantage.co/query?function=FEDERAL_FUNDS_RATE&interval=daily&apikey={api_key}' 
r = requests.get(url)
response_data = r.json()
